# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/matth426/Calculus-with-Python-Programming/blob/main/notebooks/calcwp_wk2_graphing_functions.ipynb)

# %% [markdown]
# # CALCWP: CALCULUS WITH PYTHON PROGRAMMING
# ## Week 2 — Graphing Functions and Transformations
#
# **Topics this week:**
# - Plotting functions with `matplotlib`
# - Using `numpy.linspace` to generate evenly spaced x-values
# - Function transformations: shifts, stretches/compressions, and reflections
#
# **By the end of this notebook, you should be able to:**
# 1. Plot a function using `numpy` and `matplotlib`.
# 2. Read and interpret a graph (identify key features by eye).
# 3. Predict how changing a function's equation affects its graph (shift, stretch, reflect).
# 4. Compare multiple functions on the same plot to see transformations side-by-side.
#
# ---

# %% [markdown]
# ## 0. Quick Recap from Week 1
#
# Last week, we evaluated functions manually, one x-value at a time:
#
# ```python
# x = 2
# f_x = x ** 2 + 3
# print("f(2) =", f_x)
# ```
#
# That works fine for *one* value. But to draw a graph, we need to evaluate a function at **hundreds** of x-values — plotting each `(x, f(x))` point and connecting them into a smooth curve. Doing that one line at a time would be painful. This is where `numpy` and `matplotlib` come in.

# %% [markdown]
# ## 1. Generating Many x-values with `numpy.linspace`
#
# `numpy` is a Python library for working with arrays of numbers efficiently. The function `linspace(start, stop, num)` creates `num` evenly spaced values between `start` and `stop`.
#
# ```python
# numpy.linspace(-5, 5, 11)
# ```
# This creates 11 evenly spaced numbers from -5 to 5.

# %%
import numpy as np

x_values = np.linspace(-5, 5, 11)
print(x_values)

# %% [markdown]
# Notice that `x_values` is not a single number — it's an **array** of numbers. The powerful part: math operations apply to the *entire array at once*, no loop needed.

# %%
y_values = x_values ** 2   # squares every value in the array at once
print(y_values)

# %% [markdown]
# **Practice 1.1:** Create an array of 21 evenly spaced x-values from -10 to 10 using `np.linspace`. Then compute and print the array of y-values for $ y = 2x + 1 $.

# %%
# Write your code here

# %% [markdown]
# <details>
# <summary><b>Click for Solution</b></summary>
#
# ```python
# # 21 evenly spaced values from -10 to 10
# x = np.linspace(-10, 10, 21)
#
# # Linear equation y = 2x + 1
# y = 2 * x + 1
#
# print("x-values:\n", x)
# print("\ny-values:\n", y)
# ```
#
# </details>

# %% [markdown]
# ## 2. Plotting with `matplotlib`
#
# Now that we can generate x and y arrays, we can plot them with `matplotlib.pyplot`, usually imported as `plt`.
#
# The basic recipe:
# ```python
# plt.plot(x_values, y_values)
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 5, 100)
y = x ** 2

plt.plot(x, y)
plt.title("Graph of f(x) = x^2")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.axhline(0, color='gray', linewidth=0.5)
plt.axvline(0, color='gray', linewidth=0.5)
plt.grid(True)
plt.show()

# %% [markdown]
# **Why 100 points?** More points make the curve look smooth. Try changing `100` to `5` in the cell above and re-run it — notice how jagged the graph becomes. This is the same idea we'll revisit later when approximating curves numerically.
#
# **Practice 2.1:** Plot $ f(x) = x^3 - 4x $ for x from -3 to 3. Add a title and axis labels.

# %%
# Write your code here

# %% [markdown]
# <details>
# <summary><b>Click for Solution</b></summary>
#
# ```python
# x = np.linspace(-3, 3, 100)
# y = x ** 3 - 4x
#
# plt.plot(x, y)
# plt.title("Graph of f(x) = x^3 - 4x")
# plt.xlabel("x")
# plt.ylabel("f(x)")
# plt.axhline(0, color='gray', linewidth=0.5)
# plt.axvline(0, color='gray', linewidth=0.5)
# plt.grid(True)
# plt.show()
# ```
#
# </details>

# %% [markdown]
# ## 3. Transformation #1 — Vertical & Horizontal Shifts
#
# Given a base function $ f(x) $, we can shift its graph:
#
# | Transformation | Effect |
# |---|---|
# | $ f(x) + k $ | Shifts graph **up** by $k$ (if $k>0$) or down (if $k<0$) |
# | $ f(x - h) $ | Shifts graph **right** by $h$ (if $h>0$) or left (if $h<0$) |
#
# Let's compare $ f(x) = x^2 $ with $ f(x) + 3 $ and $ f(x - 2) $ on the same plot.

# %%
x = np.linspace(-6, 6, 200)

y1 = x ** 2            # original
y2 = x ** 2 + 3         # shifted up by 3
y3 = (x - 2) ** 2       # shifted right by 2

plt.plot(x, y1, label="f(x) = x^2")
plt.plot(x, y2, label="f(x) + 3")
plt.plot(x, y3, label="f(x - 2)")

plt.title("Vertical and Horizontal Shifts")
plt.xlabel("x")
plt.ylabel("y")
plt.axhline(0, color='gray', linewidth=0.5)
plt.axvline(0, color='gray', linewidth=0.5)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Notice:
# - The **orange** curve (`f(x) + 3`) is the same shape as the blue curve, just moved **up**.
# - The **green** curve (`f(x - 2)`) is the same shape, moved **right**.
#
# **Practice 3.1:** Starting from $ f(x) = x^2 $, plot $ f(x) - 4 $ (shift down) and $ f(x + 3) $ (shift left) together with the original on one graph. Use `label=` and `plt.legend()` like the example above.

# %%
# Write your code here

# %% [markdown]
# <details>
# <summary><b>Click for Solution</b></summary>
#
# ```python
# x = np.linspace(-6, 6, 200)
#
# y1 = x ** 2            # original
# y2 = x ** 2 - 4         # shifted down by 4
# y3 = (x + 3) ** 2       # shifted left by 3
#
# plt.plot(x, y1, label="f(x) = x^2")
# plt.plot(x, y2, label="f(x) - 4")
# plt.plot(x, y3, label="f(x + 3)")
#
# plt.title("Vertical and Horizontal Shifts")
# plt.xlabel("x")
# plt.ylabel("y")
# plt.axhline(0, color='gray', linewidth=0.5)
# plt.axvline(0, color='gray', linewidth=0.5)
# plt.legend()
# plt.grid(True)
# plt.show()
# ```
#
# </details>

# %% [markdown]
# ## 4. Transformation #2 — Vertical Stretch/Compression
#
# Multiplying a function by a constant $a$ changes how "tall" or "flat" it looks:
#
# $$ y = a \cdot f(x) $$
#
# - If $ |a| > 1 $: the graph stretches **vertically** (looks taller/narrower)
# - If $ 0 < |a| < 1 $: the graph compresses **vertically** (looks flatter/wider)
# - If $ a $ is negative: the graph also **reflects** (flips) — covered next

# %% [markdown]
# **Practice 4.1:** Plot $ f(x) = x^2 $ alongside $ 5f(x) $ and $ 0.2f(x) $. Which one looks the "narrowest"? Which looks the "widest"? Write your answer as a comment in the code cell.

# %%
# Write your code here


# Your observation:

# %% [markdown]
# <details>
# <summary><b>Click for Solution</b></summary>
#
# ```python
# x = np.linspace(-6, 6, 200)
#
# y1 = x ** 2            # original
# y2 = 5 * (x ** 2)      # vertically stretched by a factor of 5
# y3 = 0.2 * (x ** 2)    # vertically compressed by a factor of 0.2
#
# plt.plot(x, y1, label="f(x) = x^2")
# plt.plot(x, y2, label="5f(x)")
# plt.plot(x, y3, label="0.2f(x)")
#
# plt.title("Vertical Stretching and Compression")
# plt.xlabel("x")
# plt.ylabel("y")
# plt.axhline(0, color='gray', linewidth=0.5)
# plt.axvline(0, color='gray', linewidth=0.5)
# plt.legend()
# plt.grid(True)
# plt.show()
#
# # --- ANALYSIS ---
# # 5f(x) looks the "narrowest" because scaling the output by 5 pulls the values up faster, creating a steep stretch.
# # 0.2f(x) looks the "widest" because multiplying by 0.2 flattens/squishes the curve closer to the x-axis.
# ```
#
# </details>

# %% [markdown]
# ## 5. Transformation #3 — Reflections
#
# - $ -f(x) $ reflects the graph **over the x-axis** (flips upside down)
# - $ f(-x) $ reflects the graph **over the y-axis** (flips left-right)

# %%
x = np.linspace(-4, 4, 200)

y1 = x ** 3          # original
y2 = -(x ** 3)        # reflected over x-axis
y3 = (-x) ** 3        # reflected over y-axis

plt.plot(x, y1, label="f(x) = x^3")
plt.plot(x, y2, label="-f(x)")
plt.plot(x, y3, label="f(-x)")

plt.title("Reflections")
plt.xlabel("x")
plt.ylabel("y")
plt.axhline(0, color='gray', linewidth=0.5)
plt.axvline(0, color='gray', linewidth=0.5)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Notice something interesting?** For $ f(x) = x^3 $, the graphs of $ -f(x) $ and $ f(-x) $ actually look identical! This is a special property of **odd functions** — you don't need to memorize this term yet, just observe it. Not every function behaves this way (try it with $x^2$ instead and see what happens).
#
# **Practice 5.1:** Using $ f(x) = x^2 $, plot $ f(x) $, $ -f(x) $, and $ f(-x) $ together. Are $ -f(x) $ and $ f(-x) $ still identical? Write a one-line comment explaining what you observe.

# %%
# Write your code here


# Your observation:

# %% [markdown]
# <details>
# <summary><b>Click for Solution</b></summary>
#
# ```python
# x = np.linspace(-6, 6, 200)
#
# y1 = x ** 2            # original
# y2 = -(x ** 2)         # reflection across the x-axis
# y3 = (-x) ** 2         # reflection across the y-axis
#
# plt.plot(x, y1, label="f(x) = x^2")
# plt.plot(x, y2, label="-f(x)")
# plt.plot(x, y3, label="f(-x)")
#
# plt.title("Reflections across Axes")
# plt.xlabel("x")
# plt.ylabel("y")
# plt.axhline(0, color='gray', linewidth=0.5)
# plt.axvline(0, color='gray', linewidth=0.5)
# plt.legend()
# plt.grid(True)
# plt.show()
#
# # --- ANALYSIS ---
# # -f(x) and f(-x) are not identical because -f(x) opens downward,
# # while f(-x) perfectly overlaps the original f(x) due to the y-axis symmetry of an even function.
# ```
#
# </details>

# %% [markdown]
# ## 6. Combining Transformations
#
# Real transformations often combine several of these at once:
#
# $$ y = a \cdot f(x - h) + k $$
#
# - $a$: vertical stretch/compression (and reflection if negative)
# - $h$: horizontal shift
# - $k$: vertical shift
#
# **Worked Example:** Starting from $ f(x) = x^2 $, graph $ y = -2(x - 1)^2 + 4 $.
#
# Reading the transformation:
# - $a = -2$: stretched by 2, and reflected (flipped upside down)
# - $h = 1$: shifted right by 1
# - $k = 4$: shifted up by 4

# %%
x = np.linspace(-4, 6, 200)

y_original = x ** 2
y_transformed = -2 * (x - 1) ** 2 + 4

plt.plot(x, y_original, label="f(x) = x^2", linestyle='--')
plt.plot(x, y_transformed, label="-2(x-1)^2 + 4")

plt.title("Combined Transformation")
plt.xlabel("x")
plt.ylabel("y")
plt.axhline(0, color='gray', linewidth=0.5)
plt.axvline(0, color='gray', linewidth=0.5)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Practice 6.1:** Starting from $ f(x) = x^2 $, predict what the graph of $ y = 3(x + 2)^2 - 5 $ will look like (write your prediction as a comment: direction of shifts, stretch or compress, any reflection). Then plot it to check your prediction.

# %%
# Your prediction (as a comment):


# Write your plotting code here

# %% [markdown]
# <details>
# <summary><b>Click for Solution</b></summary>
#
# ```python
# x = np.linspace(-6, 6, 200)
#
# y1 = x ** 2                  # parent function
# y2 = 3 * (x + 2) ** 2 - 5    # transformed function
#
# plt.plot(x, y1, label="f(x) = x^2")
# plt.plot(x, y2, label="y = 3(x+2)^2 - 5")
#
# plt.title("Combined Function Transformations")
# plt.xlabel("x")
# plt.ylabel("y")
# plt.axhline(0, color='gray', linewidth=0.5)
# plt.axvline(0, color='gray', linewidth=0.5)
# plt.legend()
# plt.grid(True)
# plt.show()
#
# # --- PREDICTION ---
# # The graph shifts LEFT by 2 units, DOWN by 5 units,
# # vertically STRETCHES by a factor of 3 (making it narrower),
# # and has NO reflection (opens upward).
#
# ```
#
# </details>

# %% [markdown]
# ## 7. Mini-Challenge
#
# A company's weekly production cost (in thousands of pesos) is modeled by:
#
# $$ C(x) = 0.5(x - 10)^2 + 20 $$
#
# where $x$ is the number of units produced (in hundreds).
#
# **Tasks:**
# 1. Plot $ C(x) $ for $x$ from 0 to 20.
# 2. By reading the graph, estimate the value of $x$ that gives the **lowest** cost, and estimate that minimum cost.
# 3. **Bonus:** Plot the base function $ y = x^2 $ on the same graph (dashed line) to visually confirm which transformations were applied to get $C(x)$.

# %%
# Task 1: Plot C(x)


# Task 2: Write your estimate as a comment


# Task 3 (Bonus): Plot y = x^2 for comparison

# %% [markdown]
# <details>
# <summary><b>Click for Solution</b></summary>
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# x = np.linspace(0, 20, 200)
#
# y1 = x ** 2                     # Base function (dashed line)
# y2 = 0.5 * (x - 10) ** 2 + 20   # Cost function C(x)
#
# plt.plot(x, y1, label="Base: f(x) = x^2", color='gray', linestyle='--')
# plt.plot(x, y2, label="Cost: C(x) = 0.5(x-10)^2 + 20", color='blue')
#
# plt.title("Weekly Production Cost Analysis")
# plt.xlabel("Units Produced (in hundreds)")
# plt.ylabel("Cost (in thousands of pesos)")
# plt.axhline(0, color='gray', linewidth=0.5)
# plt.axvline(0, color='gray', linewidth=0.5)
#
# # Set axes limits to keep the comparison clean and focused on the relevant production range
# plt.xlim(0, 20)
# plt.ylim(0, 100)
#
# plt.legend()
# plt.grid(True)
# plt.show()
#
# # --- COST ESTIMATION & TRANSFORMATION ANALYSIS ---
# # 1. Looking at the bottom vertex of the solid blue curve C(x):
# #    - The value of x that minimizes cost is x = 10 (which means 1,000 units).
# #    - The estimated minimum cost at this point is 20 (which means 20,000 pesos).
# #
# # 2. Comparing it to the dashed base curve visually confirms the following transformations:
# #    - Shifted RIGHT by 10 units.
# #    - Vertically COMPRESSED by a factor of 0.5 (making it wider).
# #    - Shifted UP by 20 units.
#
# ```
#
# </details>

# %% [markdown]
# ## Summary
#
# This week, you learned:
# - How to generate arrays of x-values with `numpy.linspace`
# - How to plot functions with `matplotlib.pyplot`
# - How vertical/horizontal shifts affect a graph: $f(x) + k$ and $f(x - h)$
# - How stretches/compressions affect a graph: $a \cdot f(x)$
# - How reflections affect a graph: $-f(x)$ and $f(-x)$
# - How to combine transformations and predict a graph's shape before plotting
#
# **Next week (Week 3):** We start Calculus proper — **limits**. We'll use tables of values and graphs (skills from this week!) to build intuition for what a limit actually means.
#
# ---
# *CALCWP — Calculus with Python Programming | Mattheus Marcus Contreras | Lab Manual Series*
