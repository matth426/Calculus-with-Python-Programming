# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/matth426/Calculus-with-Python-Programming/blob/main/notebooks/calcwp_wk12_review_exam.ipynb)

# %% [markdown]
# # CALCWP: CALCULUS WITH PYTHON PROGRAMMING
# ## Week 12 — Review and Lab Exam (Differential Calculus)
#
# This notebook has two parts:
#
# - **Part 1: Review** — a quick-reference recap of every tool and concept from Weeks 1–11, with short "Quick Check" questions (solutions included, for self-study).
# - **Part 2: Lab Exam** — a set of graded problems covering the full Differential Calculus unit. **No solutions are provided** in this part — this is meant to be completed and submitted.
#
# ---

# %% [markdown]
# # Part 1: Review
#
# Work through this section at your own pace before attempting the Lab Exam below. Each topic has a one-line reminder of the key tool, plus a Quick Check question with a hidden solution.

# %% [markdown]
# ## Weeks 1–4: Foundations, Graphing, Limits, Continuity
#
# | Concept | Key tool |
# |---|---|
# | Evaluating a function | Substitute directly, or `expr.subs(x, value)` |
# | Plotting a function | `numpy.linspace()` + `matplotlib.pyplot.plot()` |
# | Estimating a limit | Build a table with a `for` loop, values approaching the target |
# | Exact limit | `sympy.limit(expr, x, a)` (use `dir='-'`/`dir='+'` for one-sided) |
# | Continuity at $x=a$ | Check: (1) $f(a)$ defined, (2) limit exists, (3) they're equal |

# %%
from sympy import symbols, limit, diff, solve, Function, Eq, Derivative, oo

x = symbols('x')

# Quick reminder: limit of a rational expression with a removable discontinuity
expr = (x**2 - 4) / (x - 2)
print(limit(expr, x, 2))

# %% [markdown]
# **Quick Check 1:** Evaluate $ \lim_{x \to 0} \dfrac{\sin(x)}{x} $ using `sympy` (this is a famous limit you may see again in later math courses).

# %%
# Write your code here

# %% [markdown]
# <details>
# <summary><b>Click for Solution</b></summary>
#
# ```python
# from sympy import sin
# print(limit(sin(x)/x, x, 0))
# ```
#
# **Answer:** 1
#
# </details>

# %% [markdown]
# ## Weeks 5–7: The Derivative, Differentiation Rules, Higher-Order & Implicit
#
# | Concept | Key tool |
# |---|---|
# | Numerical derivative | Difference quotient: `(f(a+h) - f(a)) / h` for small `h` |
# | Exact derivative | `sympy.diff(expr, x)` |
# | Power/sum/product/quotient/chain rules | All handled automatically by `diff()` |
# | Higher-order derivatives | `diff(expr, x, n)` or nested `diff(diff(expr, x), x)` |
# | Implicit differentiation | `Function('y')(x)`, `Eq(...)`, differentiate both sides, `solve(..., Derivative(y, x))` |

# %%
f = x**3 * (x + 2)**2
print("f'(x) =", diff(f, x))
print("f''(x) =", diff(f, x, 2))

# %% [markdown]
# **Quick Check 2:** Find $\dfrac{dy}{dx}$ for the implicit equation $ y^3 + xy = 10 $.

# %%
# Write your code here

# %% [markdown]
# <details>
# <summary><b>Click for Solution</b></summary>
#
# ```python
# y = Function('y')(x)
# eq = Eq(y**3 + x*y, 10)
# differentiated = Eq(diff(eq.lhs, x), diff(eq.rhs, x))
# dy_dx = solve(differentiated, Derivative(y, x))[0]
# print("dy/dx =", dy_dx)
# ```
#
# </details>

# %% [markdown]
# ## Week 8: Motion Problems
#
# | Concept | Key tool |
# |---|---|
# | Position → velocity → acceleration | $v(t) = s'(t)$, $a(t) = v'(t) = s''(t)$ |
# | Direction of motion | Sign of $v(t)$: positive = forward, negative = backward |
# | Speeding up / slowing down | Same sign (v, a) = speeding up; opposite signs = slowing down |
# | Distance vs. displacement | Displacement = $s(b)-s(a)$; total distance sums absolute legs between rest points |

# %% [markdown]
# **Quick Check 3:** For $ s(t) = t^3 - 6t^2 $, find $v(t)$ and determine whether the object is speeding up or slowing down at $t=1$.

# %%
# Write your code here

# %% [markdown]
# <details>
# <summary><b>Click for Solution</b></summary>
#
# ```python
# t = symbols('t')
# s = t**3 - 6*t**2
# v = diff(s, t)
# a = diff(s, t, 2)
#
# v_at_1 = v.subs(t, 1)
# a_at_1 = a.subs(t, 1)
# print("v(1) =", v_at_1, ", a(1) =", a_at_1)
# ```
#
# **Answer:** $v(1)=-9$ (negative), $a(1)=-6$ (negative) — same sign, so the object is **speeding up**.
#
# </details>

# %% [markdown]
# ## Week 9: Curve Sketching
#
# | Concept | Key tool |
# |---|---|
# | Critical points | `solve(diff(f, x), x)` |
# | Increasing/decreasing | Sign of $f'(x)$ at test points between critical points |
# | First Derivative Test | Compare sign of $f'$ just before/after a critical point |
# | Inflection points | `solve(diff(f, x, 2), x)`, check for a sign change in $f''$ |

# %% [markdown]
# **Quick Check 4:** Find the critical points of $ f(x) = x^3 - 6x^2 + 9x $ and classify each as a local max or local min.

# %%
# Write your code here

# %% [markdown]
# <details>
# <summary><b>Click for Solution</b></summary>
#
# ```python
# x = symbols('x')
# f = x**3 - 6*x**2 + 9*x
# f_prime = diff(f, x)
# critical_pts = solve(f_prime, x)
# print("Critical points:", critical_pts)
#
# for c in critical_pts:
#     before = f_prime.subs(x, c - 0.1)
#     after = f_prime.subs(x, c + 0.1)
#     kind = "LOCAL MAX" if before > 0 and after < 0 else "LOCAL MIN"
#     print(f"x={c}: {kind}")
# ```
#
# **Answer:** $x=1$ is a local maximum, $x=3$ is a local minimum.
#
# </details>

# %% [markdown]
# ## Week 10: Optimization
#
# | Concept | Key tool |
# |---|---|
# | Absolute max/min on $[a,b]$ | Evaluate $f$ at critical points AND endpoints; compare |
# | Word problems | Constraint equation → reduce to one variable → optimize |
# | Numerical optimization | `scipy.optimize.minimize_scalar(f, bounds=(a,b), method='bounded')` |
# | Finding a maximum with `minimize_scalar` | Minimize $-f(x)$ instead, then negate the result |

# %% [markdown]
# **Quick Check 5:** Find the absolute maximum of $ f(x) = -x^2 + 4x + 1 $ on $[0, 5]$.

# %%
# Write your code here

# %% [markdown]
# <details>
# <summary><b>Click for Solution</b></summary>
#
# ```python
# x = symbols('x')
# f = -x**2 + 4*x + 1
# f_prime = diff(f, x)
# critical_pts = solve(f_prime, x)
#
# candidates = [c for c in critical_pts if 0 <= c <= 5] + [0, 5]
# for c in candidates:
#     print(f"f({c}) = {f.subs(x, c)}")
# ```
#
# **Answer:** Absolute maximum is $f(2)=5$.
#
# </details>

# %% [markdown]
# ## Week 11: Related Rates
#
# | Concept | Key tool |
# |---|---|
# | Setting up | `Function('x')(t)` for each time-dependent quantity |
# | Differentiating | `diff(equation.lhs, t)` and `diff(equation.rhs, t)`, wrapped in `Eq(...)` |
# | Solving for a rate | `solve(differentiated_eq, Derivative(target, t))[0]` |
# | Missing values | Always pull from the **original** (undifferentiated) equation |

# %% [markdown]
# **Quick Check 6:** A square's side length $s$ is increasing at $2$ cm/s. How fast is the area $A=s^2$ increasing when $s=5$ cm?

# %%
# Write your code here

# %% [markdown]
# <details>
# <summary><b>Click for Solution</b></summary>
#
# ```python
# t = symbols('t')
# s = Function('s')(t)
# A = Function('A')(t)
#
# area_eq = Eq(A, s**2)
# differentiated = Eq(diff(area_eq.lhs, t), diff(area_eq.rhs, t))
# dA_dt = differentiated.rhs.subs({s: 5, Derivative(s, t): 2})
# print("dA/dt =", dA_dt, "cm^2/s")
# ```
#
# **Answer:** 20 cm²/s
#
# </details>

# %% [markdown]
# ---
#
# # Part 2: Lab Exam — Differential Calculus
#
# **Instructions:**
# - This exam covers Weeks 1–11 (limits through related rates).
# - You may use `sympy`, `numpy`, `matplotlib`, and `scipy` freely — this is an open-tools exam. What matters is that you set up each problem correctly and interpret your results.
# - Show your work in the code cells provided. Add comments explaining your reasoning where the problem asks for interpretation, not just a number.
# - Answer every part of each problem — partial credit is given for correct setup even if a later step has an error.
# - No solutions are provided in this section. Save and submit this notebook when finished.
#
# ---
#
# ### Problem 1 — Limits (10 points)
#
# Evaluate the following limits using `sympy`:
#
# a) $ \displaystyle\lim_{x \to 3} \frac{x^2 - 9}{x - 3} $
#
# b) $ \displaystyle\lim_{x \to \infty} \frac{5x^2 + 2}{2x^2 - 1} $
#
# c) $ \displaystyle\lim_{x \to 2^-} \dfrac{1}{x-2} $ and $ \displaystyle\lim_{x \to 2^+} \dfrac{1}{x-2} $. Does the two-sided limit exist? Explain in a comment.

# %%
# Problem 1a


# Problem 1b


# Problem 1c

# %% [markdown]
# ### Problem 2 — Continuity (10 points)
#
# Consider $ f(x) = \dfrac{x^2 - 5x + 6}{x - 2} $.
#
# a) Is $f$ continuous at $x=2$? Justify your answer using the three-part definition of continuity (you may use `sympy` to help check each condition).
#
# b) What value would need to be assigned to $f(2)$ to make $f$ continuous there? (This is called a "removable discontinuity.")

# %%
# Problem 2a


# Problem 2b

# %% [markdown]
# ### Problem 3 — Differentiation Rules (15 points)
#
# Find the derivative of each function using `sympy.diff()`. Simplify your results.
#
# a) $ f(x) = (3x^2 - 1)(x^3 + 4x) $ (product rule)
#
# b) $ g(x) = \dfrac{x^2 + 1}{x - 3} $ (quotient rule)
#
# c) $ h(x) = (5x - 2)^6 $ (chain rule)

# %%
# Problem 3a


# Problem 3b


# Problem 3c

# %% [markdown]
# ### Problem 4 — Higher-Order and Implicit Differentiation (10 points)
#
# a) Find the second derivative of $ f(x) = x^4 - 6x^2 + 3x $.
#
# b) Use implicit differentiation to find $\dfrac{dy}{dx}$ for $ x^2y + y^3 = 2x $.

# %%
# Problem 4a


# Problem 4b

# %% [markdown]
# ### Problem 5 — Motion (15 points)
#
# An object moves along a line with position $ s(t) = t^3 - 12t^2 + 36t $ (in meters), for $0 \le t \le 10$ seconds.
#
# a) Find $v(t)$ and $a(t)$.
#
# b) Find all times when the object is at rest.
#
# c) Determine whether the object is speeding up or slowing down at $t=1$ and at $t=5$.
#
# d) Compute the total distance traveled from $t=0$ to $t=8$.

# %%
# Problem 5a


# Problem 5b


# Problem 5c


# Problem 5d

# %% [markdown]
# ### Problem 6 — Curve Sketching (15 points)
#
# Consider $ f(x) = x^4 - 8x^2 + 5 $.
#
# a) Find all critical points and classify each as a local max or local min.
#
# b) Find all inflection points and determine the concavity on either side of each.
#
# c) Produce an annotated `matplotlib` graph showing the function with all critical points and inflection points labeled.

# %%
# Problem 6a


# Problem 6b


# Problem 6c

# %% [markdown]
# ### Problem 7 — Optimization (15 points)
#
# A rectangular pen is to be built using 80 meters of fencing, divided into two equal sections by a fence down the middle (parallel to one pair of sides). (So there are 3 vertical sections of fence plus 2 horizontal sections — sketch it if that helps.)
#
# a) Write the constraint equation relating the pen's width $x$ (the length of each of the 3 vertical fence pieces) and length $y$ (the length of each of the 2 horizontal fence pieces).
#
# b) Write the total enclosed area $A$ as a function of a single variable.
#
# c) Find the dimensions that maximize the enclosed area, using `sympy`.
#
# d) Confirm your answer using `scipy.optimize.minimize_scalar()`.

# %%
# Problem 7a (as a comment)


# Problem 7b


# Problem 7c


# Problem 7d

# %% [markdown]
# ### Problem 8 — Related Rates (10 points)
#
# A rectangular water tank has a fixed width of 4 meters and a fixed length of 10 meters. Water is being pumped in at a rate of $\dfrac{dV}{dt} = 6$ cubic meters per minute, where $V$ is the volume of water in the tank.
#
# a) Write the volume $V$ as a function of the water height $h$ (using the fixed width and length).
#
# b) Set up and solve for $\dfrac{dh}{dt}$, the rate at which the water level is rising. (Hint: since width and length are constant, this relationship is simpler than the cone example from Week 11 — you may not even need `sympy`'s implicit differentiation tools if you reason it through directly, but you're welcome to use them.)

# %%
# Problem 8a


# Problem 8b

# %% [markdown]
# ---
#
# **End of Lab Exam.** Double-check that every code cell runs without errors before submitting, and that any interpretation questions (Problems 1c, 2, 5c) are answered in comments or markdown, not just left as bare numbers.

# %% [markdown]
# ---
#
# # Answer Key
#
# Full worked solutions for every problem in the Lab Exam. Each is collapsed by default — expand only after attempting the problem yourself, or once your work has been submitted/graded.

# %% [markdown]
# <details>
# <summary><b>Problem 1 — Solution</b></summary>
#
# ```python
# from sympy import symbols, limit, oo
#
# x = symbols('x')
#
# # 1a
# print(limit((x**2 - 9)/(x - 3), x, 3))
#
# # 1b
# print(limit((5*x**2 + 2)/(2*x**2 - 1), x, oo))
#
# # 1c
# print(limit(1/(x - 2), x, 2, dir='-'))
# print(limit(1/(x - 2), x, 2, dir='+'))
# ```
#
# **Answers:**
# a) 6
# b) 5/2
# c) Left-hand limit is $-\infty$, right-hand limit is $+\infty$. Since they don't approach the same finite value (they don't even agree in sign), the two-sided limit **does not exist**.
#
# </details>

# %% [markdown]
# <details>
# <summary><b>Problem 2 — Solution</b></summary>
#
# ```python
# from sympy import simplify
#
# f = (x**2 - 5*x + 6) / (x - 2)
# print(simplify(f))          # x - 3, for x != 2
# print(limit(f, x, 2))       # -1
# ```
#
# **Answers:**
# a) $f(x)$ simplifies to $x-3$ for all $x\neq2$, but $f(2)$ itself is undefined (0/0) — condition 1 of continuity fails, so $f$ is **discontinuous** at $x=2$, even though the limit there exists and equals $-1$.
# b) Assigning $f(2) = -1$ would remove the discontinuity, since that matches the limit.
#
# </details>

# %% [markdown]
# <details>
# <summary><b>Problem 3 — Solution</b></summary>
#
# ```python
# from sympy import diff, simplify
#
# f = (3*x**2 - 1) * (x**3 + 4*x)
# print(simplify(diff(f, x)))
#
# g = (x**2 + 1) / (x - 3)
# print(simplify(diff(g, x)))
#
# h = (5*x - 2)**6
# print(diff(h, x))
# ```
#
# **Answers:**
# a) $f'(x) = 15x^4 + 33x^2 - 4$
# b) $g'(x) = \dfrac{x^2 - 6x - 1}{(x-3)^2}$
# c) $h'(x) = 30(5x-2)^5$
#
# </details>

# %% [markdown]
# <details>
# <summary><b>Problem 4 — Solution</b></summary>
#
# ```python
# from sympy import Function, Eq, Derivative, solve
#
# f = x**4 - 6*x**2 + 3*x
# print(diff(f, x, 2))
#
# y = Function('y')(x)
# eq = Eq(x**2*y + y**3, 2*x)
# differentiated = Eq(diff(eq.lhs, x), diff(eq.rhs, x))
# print(solve(differentiated, Derivative(y, x))[0])
# ```
#
# **Answers:**
# a) $f''(x) = 12x^2 - 12$
# b) $\dfrac{dy}{dx} = \dfrac{2 - 2xy}{x^2 + 3y^2}$
#
# </details>

# %% [markdown]
# <details>
# <summary><b>Problem 5 — Solution</b></summary>
#
# ```python
# t = symbols('t')
# s = t**3 - 12*t**2 + 36*t
# v = diff(s, t)
# a = diff(s, t, 2)
# print("v(t) =", v, " a(t) =", a)
#
# rest_times = solve(v, t)
# print("Rest times:", rest_times)
#
# print("v(1)=", v.subs(t,1), "a(1)=", a.subs(t,1))
# print("v(5)=", v.subs(t,5), "a(5)=", a.subs(t,5))
#
# checkpoints = sorted(set([0] + rest_times + [8]))
# positions = {c: s.subs(t, c) for c in checkpoints}
# total_distance = sum(
#     abs(positions[checkpoints[i+1]] - positions[checkpoints[i]])
#     for i in range(len(checkpoints) - 1)
# )
# print("Positions:", positions)
# print("Total distance (0 to 8):", total_distance)
# ```
#
# **Answers:**
# a) $v(t) = 3t^2 - 24t + 36$, $a(t) = 6t - 24$
# b) Rest times at $t=2$ and $t=6$
# c) At $t=1$: $v=15>0$, $a=-18<0$ — opposite signs, so **slowing down**. At $t=5$: $v=-9<0$, $a=6>0$ — opposite signs, so **slowing down** as well (approaching the rest point at $t=6$).
# d) Positions at checkpoints: $s(0)=0$, $s(2)=32$, $s(6)=0$, $s(8)=32$. Total distance traveled $= |32-0|+|0-32|+|32-0| = 96$ meters. (Note: displacement over the same interval is only $32-0=32$ meters — much less than the total distance, since the object reversed direction twice.)
#
# </details>

# %% [markdown]
# <details>
# <summary><b>Problem 6 — Solution</b></summary>
#
# ```python
# f = x**4 - 8*x**2 + 5
# f_prime = diff(f, x)
# critical_pts = solve(f_prime, x)
# print("Critical points:", critical_pts)
#
# for c in critical_pts:
#     before = f_prime.subs(x, c - 0.1)
#     after = f_prime.subs(x, c + 0.1)
#     kind = "LOCAL MAX" if before > 0 and after < 0 else ("LOCAL MIN" if before < 0 and after > 0 else "NEITHER")
#     print(f"x={c}: {kind}")
#
# f_double_prime = diff(f, x, 2)
# inflection_pts = solve(f_double_prime, x)
# print("Inflection points:", inflection_pts)
# ```
#
# **Answers:**
# a) Critical points at $x=-2$ (local min), $x=0$ (local max), $x=2$ (local min).
# b) Inflection points at $x=-\dfrac{2\sqrt3}{3}$ and $x=\dfrac{2\sqrt3}{3}$ (approximately $\pm1.15$). The curve is concave down between these two points and concave up outside that interval.
# c) The graph should be an upward-opening "W" shape (a quartic with two dips), narrower/flatter near the origin due to the concave-down region between the inflection points.
#
# </details>

# %% [markdown]
# <details>
# <summary><b>Problem 7 — Solution</b></summary>
#
# ```python
# xs = symbols('xs', positive=True)
#
# # Constraint: 3x + 2y = 80  -->  y = (80 - 3x) / 2
# A = xs * (80 - 3*xs) / 2
# A_prime = diff(A, xs)
# critical_x = solve(A_prime, xs)
# print("Critical x:", critical_x)
#
# best_x = critical_x[0]
# best_y = (80 - 3*best_x) / 2
# print("x =", best_x, ", y =", best_y, ", Area =", A.subs(xs, best_x))
#
# from scipy.optimize import minimize_scalar
# def neg_area(x_val):
#     return -(x_val * (80 - 3*x_val) / 2)
# result = minimize_scalar(neg_area, bounds=(0, 80/3), method='bounded')
# print("scipy x:", result.x, ", scipy area:", -result.fun)
# ```
#
# **Answers:**
# a) Constraint: $3x + 2y = 80$
# b) $ A(x) = x \cdot y = x\left(\dfrac{80-3x}{2}\right) = 40x - 1.5x^2 $
# c) $x = \dfrac{40}{3} \approx 13.33$ m, $y = 20$ m, maximum area $= \dfrac{800}{3} \approx 266.67$ m²
# d) `scipy.optimize.minimize_scalar()` should return $x\approx13.33$ and area $\approx266.67$, confirming the symbolic answer.
#
# </details>

# %% [markdown]
# <details>
# <summary><b>Problem 8 — Solution</b></summary>
#
# ```python
# from sympy import Function, Eq, Derivative
#
# h = Function('h')(t)
# V = Function('V')(t)
#
# # Width = 4, length = 10 are constants, so V = 4 * 10 * h = 40h
# volume_eq = Eq(V, 40*h)
# differentiated = Eq(diff(volume_eq.lhs, t), diff(volume_eq.rhs, t))
# print(differentiated)
#
# dh_dt = solve(differentiated, Derivative(h, t))[0]
# print("dh/dt formula:", dh_dt)
# print("dh/dt value:", dh_dt.subs(Derivative(V, t), 6))
# ```
#
# **Answers:**
# a) $V = 4 \times 10 \times h = 40h$ (since width and length are fixed, this is really just a straight-line relationship, not implicit differentiation in the Week 7 sense — but the related-rates *process* still applies).
# b) Differentiating: $\dfrac{dV}{dt} = 40\dfrac{dh}{dt}$. Substituting $\dfrac{dV}{dt}=6$: $\dfrac{dh}{dt} = \dfrac{6}{40} = \dfrac{3}{20} = 0.15$ meters per minute.
#
# </details>

# %% [markdown]
# ---
# *CALCWP — Calculus with Python Programming | Mattheus Marcos Contreras | Lab Manual Series*
